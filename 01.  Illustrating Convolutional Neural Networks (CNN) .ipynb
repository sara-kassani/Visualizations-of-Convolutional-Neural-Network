# %% [markdown]
# # Source of ConvNet Drawer Library
# ### https://github.com/yu4u/convnet-drawer

# %%
from src.convnet_drawer import Model, Conv2D, MaxPooling2D, Flatten, Dense
from matplotlib_util import save_model_to_file

import matplotlib.pyplot as plt
from IPython.display import SVG

# %matplotlib inline

# %%
model = Model(input_shape=(227, 227, 3))
model.add(Conv2D(96, (11, 11), (4, 4)))
model.add(MaxPooling2D((3, 3), strides=(2, 2)))
model.add(Conv2D(256, (5, 5), padding="same"))
model.add(MaxPooling2D((3, 3), strides=(2, 2)))
model.add(Conv2D(384, (3, 3), padding="same"))
model.add(Conv2D(384, (3, 3), padding="same"))
model.add(Conv2D(256, (3, 3), padding="same"))
model.add(MaxPooling2D((3, 3), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(4096))
model.add(Dense(4096))
model.add(Dense(1000))

# %%
# save as svg file
model.save_fig("example.svg")

# save via matplotlib
# save_model_to_file(model, "example.pdf")

# %%
display(SVG('example.svg'))

# %%
# Baseline model
model = Model(input_shape=(150, 150, 3))
model.add(Conv2D(32, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512))
model.add(Dense(1))

# %%
model.save_fig("baseline.svg")

# %%
display(SVG('baseline.svg'))

# %%
filter_size = (3, 3)
pool_size = (2, 2)
drop_out_dense = 0.5
drop_out_conv = 0.25
padding = 'same'
model = Model(input_shape=(150, 150, 3))
model.add(Conv2D(32, kernel_size=filter_size))
model.add(Conv2D(32, kernel_size=filter_size))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Conv2D(64, kernel_size=filter_size))
model.add(Conv2D(64, kernel_size=filter_size))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Conv2D(96, kernel_size=filter_size))
model.add(Conv2D(96, kernel_size=filter_size))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Conv2D(128, kernel_size=filter_size))
model.add(Conv2D(128, kernel_size=filter_size))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Flatten())
model.add(Dense(512))

model.add(Dense(128))

model.add(Dense(2))

# %%
model.save_fig("FCN.svg")

# %%
display(SVG('baseline.svg'))
